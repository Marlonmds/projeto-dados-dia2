# %% [markdown]
# <a href="https://colab.research.google.com/github/Marlonmds/projeto-dados-dia2/blob/main/Meu_primeiro_algoritmo_EBAC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operadores Aritiméticos

# %%
# Adição
10 + 2
# Out:
# 12

# %%
# Subtração
10 - 2
# Out:
# 8

# %%
# Multiplicação
10 * 2
# Out:
# 20

# %%
# Divisão
10 / 2
# Out:
# 5.0

# %%
# Divisão inteira
10 // 2
# Out:
# 5

# %%
# Resto da divisão
10 % 2
# Out:
# 0

# %%
# Potenciação
10 ** 2
# Out:
# 100

# %% [markdown]
# # Operadores Relacionais

# %%
# Menor
10 < 2
# Out:
# False

# %%
# Menor ou Igual
10 <= 2
# Out:
# False

# %%
# Maior
10 > 2
# Out:
# True

# %%
# Maior ou Igual
10 >= 2
# Out:
# True

# %%
# Igual
7 == 7
# Out:
# True

# %%
# Diferente
7 != 7
# Out:
# False

# %% [markdown]
# # Operadores Logicos

# %% [markdown]
# *   And
# *   Or
# *   Not

# %% [markdown]
# # Tabela Verdade

# %% [markdown]
# And

# %%
print(10 > 2 and 4 < 6)           # V and V - V
print(10 > 2 and 4 > 6)           # V and F - F
print(10 < 2 and 4 < 6)           # V and F - F
print(10 < 2 and 4 > 6)           # F and F - F
# Out:
# True
# False
# False
# False

# %% [markdown]
# Or

# %%
print(10 > 2 and 4 < 6)           # V and V - V
print(10 > 2 and 4 > 6)           # V and F - V
print(10 < 2 and 4 < 6)           # V and F - V
print(10 < 2 and 4 > 6)           # F and F - F
# Out:
# True
# False
# False
# False

# %% [markdown]
# "Not"

# %%
not 10 > 2  #v - f

# %%
not 10 < 2  #f - v
# Out:
# True
